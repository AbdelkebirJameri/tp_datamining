# %% [markdown]
# # Abdelkebeir Jameri

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Upload and export data

# %%
data=pd.read_csv("cars.csv",delimiter=';', encoding='latin-1')

# %%
data.head(10)
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1          Buick Skylark 320  15.0          8         350.0       165.0
# 2         Plymouth Satellite  18.0          8         318.0       150.0
# 3              AMC Rebel SST  16.0          8         304.0       150.0
# 4                Ford Torino  17.0          8         302.0       140.0
# 5           Ford Galaxie 500  15.0          8         429.0       198.0
# 6           Chevrolet Impala  14.0          8         454.0       220.0
# 7          Plymouth Fury iii  14.0          8         440.0       215.0
# 8           Pontiac Catalina  14.0          8         455.0       225.0
# 9         AMC Ambassador DPL  15.0          8         390.0       190.0
#
#    Weight  Acceleration  Model Origin
# 0  3504.0          12.0     70     US
# 1  3693.0          11.5     70     US
# 2  3436.0          11.0     70     US
# ...

# %%
data.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %% [markdown]
# # Visualisation univariée :

# %%
sns.distplot(data["Model"])
# Out:
# <AxesSubplot: xlabel='Model', ylabel='Density'>

# %%
sns.displot(data['Model'], kde = True,color ='red', bins = 10)

# %%
sns.kdeplot(data["Model"])
# Out:
# <AxesSubplot: xlabel='Model', ylabel='Density'>

# %%
sns.histplot(data.Model)
# Out:
# <AxesSubplot: xlabel='Model', ylabel='Count'>

# %%
sns.countplot(data.Cylinders)
# Out:
# <AxesSubplot: ylabel='count'>

# %% [markdown]
# # Visualisation des boites à moustaches

# %%
sns.boxplot(x =data.Model, y =data.MPG, data = data)
# Out:
# <AxesSubplot: xlabel='Model', ylabel='MPG'>

# %%
sns.violinplot(x =data.Model, y =data.MPG, data = data)
# Out:
# <AxesSubplot: xlabel='Model', ylabel='MPG'>

# %% [markdown]
# ## pour la boite a mostache la mellieure fonction c'est boxplot , puisque nous donne une vision claire sur les valeurs adherents

# %% [markdown]
# # Analyse bivariée

# %% [markdown]
# # #Nuage de points :

# %%
sns.scatterplot(data=data, x="Model", y="MPG")
# Out:
# <AxesSubplot: xlabel='Model', ylabel='MPG'>

# %%
sns.scatterplot(data=data, x="Horsepower", y="Displacement",hue="Model",palette="deep")
# Out:
# <AxesSubplot: xlabel='Horsepower', ylabel='Displacement'>

# %%
sns.relplot( data=data, x="Horsepower", y="Displacement",kind="scatter" )

# %%
sns.stripplot(data=data, y="Horsepower",x='Displacement', hue='Model')
# Out:
# <AxesSubplot: xlabel='Displacement', ylabel='Horsepower'>

# %%
sns.swarmplot(data=data, x="Cylinders",y='Acceleration', hue='Model',legend=False)
# Out:
# <AxesSubplot: xlabel='Cylinders', ylabel='Acceleration'>

# %%
sns.catplot( data=data, kind="swarm", x="Horsepower", y="Acceleration" )

# %% [markdown]
# # Relations entre les variables catégorielles

# %%
sns.jointplot(data=data, x="Horsepower", y="Acceleration", hue="Model")

# %%
sns.jointplot(data=data, x="Horsepower", y="Acceleration")

# %% [markdown]
# <h2> creation d'une dataframe avec qlq colonnes

# %%
data.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
data1=data.copy()

# %%
data2=data1.drop(['Car', 'MPG', 'Acceleration','Weight'],axis=1)
data2
# Out:
#      Cylinders  Displacement  Horsepower  Model  Origin
# 0            8         307.0       130.0     70      US
# 1            8         350.0       165.0     70      US
# 2            8         318.0       150.0     70      US
# 3            8         304.0       150.0     70      US
# 4            8         302.0       140.0     70      US
# ..         ...           ...         ...    ...     ...
# 401          4         140.0        86.0     82      US
# 402          4          97.0        52.0     82  Europe
# 403          4         135.0        84.0     82      US
# 404          4         120.0        79.0     82      US
# 405          4         119.0        82.0     82      US
#
# [406 rows x 5 columns]

# %%
sns.pairplot(data2)

# %%
sns.pairplot(data2, hue="Model")

# %%
sns.pairplot(data2, kind="kde")

# %%
sns.pairplot(data2, corner=True)

# %%
g = sns.PairGrid(data2)
g.map(sns.scatterplot)

# %% [markdown]
# # Relations entre les variables catégorielles

# %%
sns.barplot(data=data, y="Cylinders", x='Origin', hue="Model")
# Out:
# <AxesSubplot: xlabel='Origin', ylabel='Cylinders'>

# %%
sns.countplot(data=data, x="Origin", hue="Model")
# Out:
# <AxesSubplot: xlabel='Origin', ylabel='count'>

# %%
sns.lmplot(data=data, x="Horsepower", y="Displacement", hue="Origin")

# %% [markdown]
# # Style

# %%
sns.set_style("whitegrid")
sns.barplot(data=data,x='Cylinders',y='Model')
# Out:
# <AxesSubplot: xlabel='Cylinders', ylabel='Model'>
